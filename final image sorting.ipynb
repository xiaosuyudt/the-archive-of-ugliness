# %%
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.models import Model

# %%
model = keras.applications.VGG16(weights='imagenet', include_top=True)

# %%
feat_extractor = Model(inputs=model.input, outputs=model.get_layer('fc2').output)

# %%
feat_extractor.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
import glob
import random

images = glob.glob('./dataset/*.jpg')

# %%
images
# Out:
# ['./dataset/Ugly Design 215.jpg',
#  './dataset/Ugly Design 201.jpg',
#  './dataset/Ugly Design 229.jpg',
#  './dataset/Ugly Design 163.jpg',
#  './dataset/Ugly Design 177.jpg',
#  './dataset/Ugly Design 70.jpg',
#  './dataset/Ugly Design 64.jpg',
#  './dataset/Ugly Design 58.jpg',
#  './dataset/Ugly Design 188.jpg',
#  './dataset/Ugly Design 59.jpg',
#  './dataset/Ugly Design 189.jpg',
#  './dataset/Ugly Design 65.jpg',
#  './dataset/Ugly Design 71.jpg',
#  './dataset/Ugly Design 176.jpg',
#  './dataset/Ugly Design 162.jpg',
#  './dataset/Ugly Design 228.jpg',
#  './dataset/Ugly Design 200.jpg',
#  './dataset/Ugly Design 214.jpg',
#  './dataset/Ugly Design 202.jpg',
#  './dataset/Ugly Design 216.jpg',
#  './dataset/Ugly Design 174.jpg',
#  './dataset/Ugly Design 160.jpg',
#  './dataset/Ugly Design 148.jpg',
#  './dataset/Ugly Design 98.jpg',
#  './dataset/Ugly Design 67.jpg',
#  './dataset/Ugly Design 73.jpg',
#  './dataset/Ugly Design 72.jpg',
#  './dataset/Ugly Design 66.jpg',
#  './dataset/Ugly Design 149.jpg',
#  './dataset/Ugly Design 99.jpg',
#  './dataset/Ugly Design 161.jpg',
#  './dataset/Ugly Design 175.jpg',
#  './dataset/Ugly Design 217.jpg',
#  './dataset/Ugly Design 203.jpg',
#  './dataset/Ugly Design 207.jpg',
#  './dataset/Ugly Design 213.jpg',
#  './dataset/Ugly Design 159.jpg',
#  './dataset/Ugly Design 89.jpg',
#  './dataset/Ugly Design 171.jpg',
#  './dataset/Ugly Design 165.jpg',
#  './dataset/Ugly Design 62.jpg',
#  './dataset/Ugly Design 76.jpg',
#  './dataset/Ugly Design 77.jpg',
#  './dataset/Ugly Design 63.jpg',
#  './dataset/Ugly Design 164.jpg',
#  './dataset/Ugly Design 170.jpg',
#  './dataset/Ugly Design 158.jpg',
#  './dataset/Ugly Design 88.jpg',
#  './dataset/Ugly Design 212.jpg',
#  './dataset/Ugly Design 206.jpg',
#  './dataset/Ugly Design 238.jpg',
#  './dataset/Ugly Design 210.jpg',
#  './dataset/Ugly Design 204.jpg',
#  './dataset/Ugly Design 166.jpg',
#  './dataset/Ugly Design 172.jpg',
#  './dataset/Ugly Design 49.jpg',
#  './dataset/Ugly Design 199.jpg',
#  './dataset/Ugly Design 75.jpg',
#  './dataset/Ugly Design 61.jpg',
#  './dataset/Ugly Design 60.jpg',
#  './dataset/Ugly Design 74.jpg',
#  './dataset/Ugly Design 48.jpg',
#  './dataset/Ugly Design 198.jpg',
#  './dataset/Ugly Design 173.jpg',
#  './dataset/Ugly Design 167.jpg',
#  './dataset/Ugly Design 205.jpg',
#  './dataset/Ugly Design 211.jpg',
#  './dataset/Ugly Design 239.jpg',
#  './dataset/Ugly Design 276.jpg',
#  './dataset/Ugly Design 262.jpg',
#  './dataset/Ugly Design 289.jpg',
#  './dataset/Ugly Design 114.jpg',
#  './dataset/Ugly Design 128.jpg',
#  './dataset/Ugly Design 13.jpg',
#  './dataset/Ugly Design 12.jpg',
#  './dataset/Ugly Design 129.jpg',
#  './dataset/Ugly Design 115.jpg',
#  './dataset/Ugly Design 288.jpg',
#  './dataset/Ugly Design 263.jpg',
#  './dataset/Ugly Design 277.jpg',
#  './dataset/Ugly Design 261.jpg',
#  './dataset/Ugly Design 275.jpg',
#  './dataset/Ugly Design 249.jpg',
#  './dataset/Ugly Design 117.jpg',
#  './dataset/Ugly Design 103.jpg',
#  './dataset/Ugly Design 10.jpg',
#  './dataset/Ugly Design 38.jpg',
#  './dataset/Ugly Design 39.jpg',
#  './dataset/Ugly Design 11.jpg',
#  './dataset/Ugly Design 116.jpg',
#  './dataset/Ugly Design 300.jpg',
#  './dataset/Ugly Design 248.jpg',
#  './dataset/Ugly Design 8.jpg',
#  './dataset/Ugly Design 274.jpg',
#  './dataset/Ugly Design 260.jpg',
#  './dataset/Ugly Design 264.jpg',
#  './dataset/Ugly Design 270.jpg',
#  './dataset/Ugly Design 112.jpg',
#  './dataset/Ugly Design 106.jpg',
#  './dataset/Ugly Design 29.jpg',
#  './dataset/Ugly Design 15.jpg',
#  './dataset/Ugly Design 14.jpg',
#  './dataset/Ugly Design 28.jpg',
#  './dataset/Ugly Design 107.jpg',
#  './dataset/Ugly Design 113.jpg',
#  './dataset/Ugly Design 271.jpg',
#  './dataset/Ugly Design 265.jpg',
#  './dataset/Ugly Design 259.jpg',
#  './dataset/Ugly Design 273.jpg',
#  './dataset/Ugly Design 267.jpg',
#  './dataset/Ugly Design 298.jpg',
#  './dataset/Ugly Design 139.jpg',
#  './dataset/Ugly Design 105.jpg',
#  './dataset/Ugly Design 111.jpg',
#  './dataset/Ugly Design 16.jpg',
#  './dataset/Ugly Design 17.jpg',
#  './dataset/Ugly Design 110.jpg',
#  './dataset/Ugly Design 104.jpg',
#  './dataset/Ugly Design 138.jpg',
#  './dataset/Ugly Design 299.jpg',
#  './dataset/Ugly Design 266.jpg',
#  './dataset/Ugly Design 272.jpg',
#  './dataset/Ugly Design 257.jpg',
#  './dataset/Ugly Design 243.jpg',
#  './dataset/Ugly Design 3.jpg',
#  './dataset/Ugly Design 294.jpg',
#  './dataset/Ugly Design 280.jpg',
#  './dataset/Ugly Design 121.jpg',
#  './dataset/Ugly Design 135.jpg',
#  './dataset/Ugly Design 109.jpg',
#  './dataset/Ugly Design 32.jpg',
#  './dataset/Ugly Design 26.jpg',
#  './dataset/Ugly Design 27.jpg',
#  './dataset/Ugly Design 33.jpg',
#  './dataset/Ugly Design 108.jpg',
#  './dataset/Ugly Design 134.jpg',
#  './dataset/Ugly Design 120.jpg',
#  './dataset/Ugly Design 281.jpg',
#  './dataset/Ugly Design 295.jpg',
#  './dataset/Ugly Design 2.jpg',
#  './dataset/Ugly Design 242.jpg',
#  './dataset/Ugly Design 256.jpg',
#  './dataset/Ugly Design 240.jpg',
#  './dataset/Ugly Design 254.jpg',
#  './dataset/Ugly Design 268.jpg',
#  './dataset/Ugly Design 283.jpg',
#  './dataset/Ugly Design 297.jpg',
#  './dataset/Ugly Design 136.jpg',
#  './dataset/Ugly Design 122.jpg',
#  './dataset/Ugly Design 25.jpg',
#  './dataset/Ugly Design 31.jpg',
#  './dataset/Ugly Design 19.jpg',
#  './dataset/Ugly Design 18.jpg',
#  './dataset/Ugly Design 30.jpg',
#  './dataset/Ugly Design 24.jpg',
#  './dataset/Ugly Design 123.jpg',
#  './dataset/Ugly Design 137.jpg',
#  './dataset/Ugly Design 296.jpg',
#  './dataset/Ugly Design 282.jpg',
#  './dataset/Ugly Design 269.jpg',
#  './dataset/Ugly Design 1.jpg',
#  './dataset/Ugly Design 255.jpg',
#  './dataset/Ugly Design 241.jpg',
#  './dataset/Ugly Design 5.jpg',
#  './dataset/Ugly Design 279.jpg',
#  './dataset/Ugly Design 245.jpg',
#  './dataset/Ugly Design 251.jpg',
#  './dataset/Ugly Design 286.jpg',
#  './dataset/Ugly Design 292.jpg',
#  './dataset/Ugly Design 133.jpg',
#  './dataset/Ugly Design 127.jpg',
#  './dataset/Ugly Design 20.jpg',
#  './dataset/Ugly Design 34.jpg',
#  './dataset/Ugly Design 35.jpg',
#  './dataset/Ugly Design 21.jpg',
#  './dataset/Ugly Design 126.jpg',
#  './dataset/Ugly Design 132.jpg',
#  './dataset/Ugly Design 293.jpg',
#  './dataset/Ugly Design 287.jpg',
#  './dataset/Ugly Design 250.jpg',
#  './dataset/Ugly Design 244.jpg',
#  './dataset/Ugly Design 278.jpg',
#  './dataset/Ugly Design 4.jpg',
#  './dataset/Ugly Design 6.jpg',
#  './dataset/Ugly Design 252.jpg',
#  './dataset/Ugly Design 246.jpg',
#  './dataset/Ugly Design 291.jpg',
#  './dataset/Ugly Design 285.jpg',
#  './dataset/Ugly Design 118.jpg',
#  './dataset/Ugly Design 124.jpg',
#  './dataset/Ugly Design 130.jpg',
#  './dataset/Ugly Design 37.jpg',
#  './dataset/Ugly Design 23.jpg',
#  './dataset/Ugly Design 36.jpg',
#  './dataset/Ugly Design 131.jpg',
#  './dataset/Ugly Design 125.jpg',
#  './dataset/Ugly Design 119.jpg',
#  './dataset/Ugly Design 284.jpg',
#  './dataset/Ugly Design 290.jpg',
#  './dataset/Ugly Design 247.jpg',
#  './dataset/Ugly Design 253.jpg',
#  './dataset/Ugly Design 7.jpg',
#  './dataset/Ugly Design 234.jpg',
#  './dataset/Ugly Design 220.jpg',
#  './dataset/Ugly Design 208.jpg',
#  './dataset/Ugly Design 142.jpg',
#  './dataset/Ugly Design 92.jpg',
#  './dataset/Ugly Design 86.jpg',
#  './dataset/Ugly Design 156.jpg',
#  './dataset/Ugly Design 181.jpg',
#  './dataset/Ugly Design 51.jpg',
#  './dataset/Ugly Design 45.jpg',
#  './dataset/Ugly Design 195.jpg',
#  './dataset/Ugly Design 79.jpg',
#  './dataset/Ugly Design 78.jpg',
#  './dataset/Ugly Design 44.jpg',
#  './dataset/Ugly Design 194.jpg',
#  './dataset/Ugly Design 180.jpg',
#  './dataset/Ugly Design 50.jpg',
#  './dataset/Ugly Design 87.jpg',
#  './dataset/Ugly Design 157.jpg',
#  './dataset/Ugly Design 143.jpg',
#  './dataset/Ugly Design 93.jpg',
#  './dataset/Ugly Design 209.jpg',
#  './dataset/Ugly Design 221.jpg',
#  './dataset/Ugly Design 235.jpg',
#  './dataset/Ugly Design 223.jpg',
#  './dataset/Ugly Design 237.jpg',
#  './dataset/Ugly Design 155.jpg',
#  './dataset/Ugly Design 85.jpg',
#  './dataset/Ugly Design 141.jpg',
#  './dataset/Ugly Design 169.jpg',
#  './dataset/Ugly Design 196.jpg',
#  './dataset/Ugly Design 46.jpg',
#  './dataset/Ugly Design 52.jpg',
#  './dataset/Ugly Design 182.jpg',
#  './dataset/Ugly Design 53.jpg',
#  './dataset/Ugly Design 183.jpg',
#  './dataset/Ugly Design 197.jpg',
#  './dataset/Ugly Design 47.jpg',
#  './dataset/Ugly Design 168.jpg',
#  './dataset/Ugly Design 90.jpg',
#  './dataset/Ugly Design 140.jpg',
#  './dataset/Ugly Design 154.jpg',
#  './dataset/Ugly Design 84.jpg',
#  './dataset/Ugly Design 236.jpg',
#  './dataset/Ugly Design 222.jpg',
#  './dataset/Ugly Design 226.jpg',
#  './dataset/Ugly Design 232.jpg',
#  './dataset/Ugly Design 178.jpg',
#  './dataset/Ugly Design 80.jpg',
#  './dataset/Ugly Design 150.jpg',
#  './dataset/Ugly Design 144.jpg',
#  './dataset/Ugly Design 94.jpg',
#  './dataset/Ugly Design 43.jpg',
#  './dataset/Ugly Design 193.jpg',
#  './dataset/Ugly Design 187.jpg',
#  './dataset/Ugly Design 57.jpg',
#  './dataset/Ugly Design 186.jpg',
#  './dataset/Ugly Design 56.jpg',
#  './dataset/Ugly Design 42.jpg',
#  './dataset/Ugly Design 192.jpg',
#  './dataset/Ugly Design 145.jpg',
#  './dataset/Ugly Design 81.jpg',
#  './dataset/Ugly Design 151.jpg',
#  './dataset/Ugly Design 179.jpg',
#  './dataset/Ugly Design 233.jpg',
#  './dataset/Ugly Design 227.jpg',
#  './dataset/Ugly Design 219.jpg',
#  './dataset/Ugly Design 231.jpg',
#  './dataset/Ugly Design 225.jpg',
#  './dataset/Ugly Design 97.jpg',
#  './dataset/Ugly Design 147.jpg',
#  './dataset/Ugly Design 153.jpg',
#  './dataset/Ugly Design 83.jpg',
#  './dataset/Ugly Design 68.jpg',
#  './dataset/Ugly Design 54.jpg',
#  './dataset/Ugly Design 184.jpg',
#  './dataset/Ugly Design 190.jpg',
#  './dataset/Ugly Design 40.jpg',
#  './dataset/Ugly Design 191.jpg',
#  './dataset/Ugly Design 41.jpg',
#  './dataset/Ugly Design 55.jpg',
#  './dataset/Ugly Design 185.jpg',
#  './dataset/Ugly Design 69.jpg',
#  './dataset/Ugly Design 152.jpg',
#  './dataset/Ugly Design 82.jpg',
#  './dataset/Ugly Design 96.jpg',
#  './dataset/Ugly Design 146.jpg',
#  './dataset/Ugly Design 224.jpg',
#  './dataset/Ugly Design 230.jpg',
#  './dataset/Ugly Design 218.jpg']

# %%
random.shuffle(images)
images = images[:300]

# %%
images
# Out:
# ['./dataset/Ugly Design 248.jpg',
#  './dataset/Ugly Design 211.jpg',
#  './dataset/Ugly Design 231.jpg',
#  './dataset/Ugly Design 296.jpg',
#  './dataset/Ugly Design 175.jpg',
#  './dataset/Ugly Design 196.jpg',
#  './dataset/Ugly Design 3.jpg',
#  './dataset/Ugly Design 195.jpg',
#  './dataset/Ugly Design 213.jpg',
#  './dataset/Ugly Design 281.jpg',
#  './dataset/Ugly Design 121.jpg',
#  './dataset/Ugly Design 179.jpg',
#  './dataset/Ugly Design 212.jpg',
#  './dataset/Ugly Design 283.jpg',
#  './dataset/Ugly Design 229.jpg',
#  './dataset/Ugly Design 210.jpg',
#  './dataset/Ugly Design 75.jpg',
#  './dataset/Ugly Design 58.jpg',
#  './dataset/Ugly Design 103.jpg',
#  './dataset/Ugly Design 172.jpg',
#  './dataset/Ugly Design 217.jpg',
#  './dataset/Ugly Design 26.jpg',
#  './dataset/Ugly Design 145.jpg',
#  './dataset/Ugly Design 298.jpg',
#  './dataset/Ugly Design 67.jpg',
#  './dataset/Ugly Design 209.jpg',
#  './dataset/Ugly Design 48.jpg',
#  './dataset/Ugly Design 91.jpg',
#  './dataset/Ugly Design 119.jpg',
#  './dataset/Ugly Design 132.jpg',
#  './dataset/Ugly Design 73.jpg',
#  './dataset/Ugly Design 148.jpg',
#  './dataset/Ugly Design 164.jpg',
#  './dataset/Ugly Design 122.jpg',
#  './dataset/Ugly Design 166.jpg',
#  './dataset/Ugly Design 183.jpg',
#  './dataset/Ugly Design 116.jpg',
#  './dataset/Ugly Design 12.jpg',
#  './dataset/Ugly Design 198.jpg',
#  './dataset/Ugly Design 74.jpg',
#  './dataset/Ugly Design 124.jpg',
#  './dataset/Ugly Design 18.jpg',
#  './dataset/Ugly Design 104.jpg',
#  './dataset/Ugly Design 38.jpg',
#  './dataset/Ugly Design 87.jpg',
#  './dataset/Ugly Design 291.jpg',
#  './dataset/Ugly Design 143.jpg',
#  './dataset/Ugly Design 136.jpg',
#  './dataset/Ugly Design 156.jpg',
#  './dataset/Ugly Design 277.jpg',
#  './dataset/Ugly Design 29.jpg',
#  './dataset/Ugly Design 240.jpg',
#  './dataset/Ugly Design 79.jpg',
#  './dataset/Ugly Design 154.jpg',
#  './dataset/Ugly Design 292.jpg',
#  './dataset/Ugly Design 34.jpg',
#  './dataset/Ugly Design 170.jpg',
#  './dataset/Ugly Design 125.jpg',
#  './dataset/Ugly Design 21.jpg',
#  './dataset/Ugly Design 64.jpg',
#  './dataset/Ugly Design 120.jpg',
#  './dataset/Ugly Design 268.jpg',
#  './dataset/Ugly Design 182.jpg',
#  './dataset/Ugly Design 142.jpg',
#  './dataset/Ugly Design 247.jpg',
#  './dataset/Ugly Design 297.jpg',
#  './dataset/Ugly Design 199.jpg',
#  './dataset/Ugly Design 106.jpg',
#  './dataset/Ugly Design 259.jpg',
#  './dataset/Ugly Design 169.jpg',
#  './dataset/Ugly Design 202.jpg',
#  './dataset/Ugly Design 289.jpg',
#  './dataset/Ugly Design 242.jpg',
#  './dataset/Ugly Design 214.jpg',
#  './dataset/Ugly Design 126.jpg',
#  './dataset/Ugly Design 235.jpg',
#  './dataset/Ugly Design 230.jpg',
#  './dataset/Ugly Design 261.jpg',
#  './dataset/Ugly Design 15.jpg',
#  './dataset/Ugly Design 52.jpg',
#  './dataset/Ugly Design 270.jpg',
#  './dataset/Ugly Design 267.jpg',
#  './dataset/Ugly Design 208.jpg',
#  './dataset/Ugly Design 96.jpg',
#  './dataset/Ugly Design 204.jpg',
#  './dataset/Ugly Design 19.jpg',
#  './dataset/Ugly Design 294.jpg',
#  './dataset/Ugly Design 273.jpg',
#  './dataset/Ugly Design 173.jpg',
#  './dataset/Ugly Design 25.jpg',
#  './dataset/Ugly Design 163.jpg',
#  './dataset/Ugly Design 130.jpg',
#  './dataset/Ugly Design 137.jpg',
#  './dataset/Ugly Design 203.jpg',
#  './dataset/Ugly Design 180.jpg',
#  './dataset/Ugly Design 123.jpg',
#  './dataset/Ugly Design 271.jpg',
#  './dataset/Ugly Design 244.jpg',
#  './dataset/Ugly Design 153.jpg',
#  './dataset/Ugly Design 262.jpg',
#  './dataset/Ugly Design 81.jpg',
#  './dataset/Ugly Design 251.jpg',
#  './dataset/Ugly Design 44.jpg',
#  './dataset/Ugly Design 220.jpg',
#  './dataset/Ugly Design 162.jpg',
#  './dataset/Ugly Design 24.jpg',
#  './dataset/Ugly Design 111.jpg',
#  './dataset/Ugly Design 159.jpg',
#  './dataset/Ugly Design 181.jpg',
#  './dataset/Ugly Design 129.jpg',
#  './dataset/Ugly Design 286.jpg',
#  './dataset/Ugly Design 47.jpg',
#  './dataset/Ugly Design 42.jpg',
#  './dataset/Ugly Design 191.jpg',
#  './dataset/Ugly Design 219.jpg',
#  './dataset/Ugly Design 243.jpg',
#  './dataset/Ugly Design 246.jpg',
#  './dataset/Ugly Design 61.jpg',
#  './dataset/Ugly Design 177.jpg',
#  './dataset/Ugly Design 185.jpg',
#  './dataset/Ugly Design 70.jpg',
#  './dataset/Ugly Design 65.jpg',
#  './dataset/Ugly Design 290.jpg',
#  './dataset/Ugly Design 216.jpg',
#  './dataset/Ugly Design 160.jpg',
#  './dataset/Ugly Design 140.jpg',
#  './dataset/Ugly Design 241.jpg',
#  './dataset/Ugly Design 43.jpg',
#  './dataset/Ugly Design 168.jpg',
#  './dataset/Ugly Design 92.jpg',
#  './dataset/Ugly Design 288.jpg',
#  './dataset/Ugly Design 97.jpg',
#  './dataset/Ugly Design 237.jpg',
#  './dataset/Ugly Design 253.jpg',
#  './dataset/Ugly Design 54.jpg',
#  './dataset/Ugly Design 86.jpg',
#  './dataset/Ugly Design 4.jpg',
#  './dataset/Ugly Design 27.jpg',
#  './dataset/Ugly Design 62.jpg',
#  './dataset/Ugly Design 8.jpg',
#  './dataset/Ugly Design 138.jpg',
#  './dataset/Ugly Design 225.jpg',
#  './dataset/Ugly Design 150.jpg',
#  './dataset/Ugly Design 293.jpg',
#  './dataset/Ugly Design 152.jpg',
#  './dataset/Ugly Design 257.jpg',
#  './dataset/Ugly Design 77.jpg',
#  './dataset/Ugly Design 149.jpg',
#  './dataset/Ugly Design 236.jpg',
#  './dataset/Ugly Design 110.jpg',
#  './dataset/Ugly Design 282.jpg',
#  './dataset/Ugly Design 250.jpg',
#  './dataset/Ugly Design 139.jpg',
#  './dataset/Ugly Design 59.jpg',
#  './dataset/Ugly Design 78.jpg',
#  './dataset/Ugly Design 287.jpg',
#  './dataset/Ugly Design 274.jpg',
#  './dataset/Ugly Design 161.jpg',
#  './dataset/Ugly Design 13.jpg',
#  './dataset/Ugly Design 118.jpg',
#  './dataset/Ugly Design 238.jpg',
#  './dataset/Ugly Design 263.jpg',
#  './dataset/Ugly Design 192.jpg',
#  './dataset/Ugly Design 71.jpg',
#  './dataset/Ugly Design 30.jpg',
#  './dataset/Ugly Design 95.jpg',
#  './dataset/Ugly Design 147.jpg',
#  './dataset/Ugly Design 272.jpg',
#  './dataset/Ugly Design 39.jpg',
#  './dataset/Ugly Design 28.jpg',
#  './dataset/Ugly Design 133.jpg',
#  './dataset/Ugly Design 300.jpg',
#  './dataset/Ugly Design 200.jpg',
#  './dataset/Ugly Design 232.jpg',
#  './dataset/Ugly Design 194.jpg',
#  './dataset/Ugly Design 188.jpg',
#  './dataset/Ugly Design 84.jpg',
#  './dataset/Ugly Design 295.jpg',
#  './dataset/Ugly Design 275.jpg',
#  './dataset/Ugly Design 50.jpg',
#  './dataset/Ugly Design 114.jpg',
#  './dataset/Ugly Design 80.jpg',
#  './dataset/Ugly Design 186.jpg',
#  './dataset/Ugly Design 76.jpg',
#  './dataset/Ugly Design 228.jpg',
#  './dataset/Ugly Design 112.jpg',
#  './dataset/Ugly Design 218.jpg',
#  './dataset/Ugly Design 144.jpg',
#  './dataset/Ugly Design 9.jpg',
#  './dataset/Ugly Design 215.jpg',
#  './dataset/Ugly Design 53.jpg',
#  './dataset/Ugly Design 151.jpg',
#  './dataset/Ugly Design 82.jpg',
#  './dataset/Ugly Design 2.jpg',
#  './dataset/Ugly Design 226.jpg',
#  './dataset/Ugly Design 221.jpg',
#  './dataset/Ugly Design 36.jpg',
#  './dataset/Ugly Design 31.jpg',
#  './dataset/Ugly Design 264.jpg',
#  './dataset/Ugly Design 7.jpg',
#  './dataset/Ugly Design 45.jpg',
#  './dataset/Ugly Design 33.jpg',
#  './dataset/Ugly Design 98.jpg',
#  './dataset/Ugly Design 193.jpg',
#  './dataset/Ugly Design 10.jpg',
#  './dataset/Ugly Design 157.jpg',
#  './dataset/Ugly Design 176.jpg',
#  './dataset/Ugly Design 234.jpg',
#  './dataset/Ugly Design 178.jpg',
#  './dataset/Ugly Design 101.jpg',
#  './dataset/Ugly Design 105.jpg',
#  './dataset/Ugly Design 174.jpg',
#  './dataset/Ugly Design 299.jpg',
#  './dataset/Ugly Design 113.jpg',
#  './dataset/Ugly Design 279.jpg',
#  './dataset/Ugly Design 190.jpg',
#  './dataset/Ugly Design 269.jpg',
#  './dataset/Ugly Design 227.jpg',
#  './dataset/Ugly Design 99.jpg',
#  './dataset/Ugly Design 205.jpg',
#  './dataset/Ugly Design 171.jpg',
#  './dataset/Ugly Design 223.jpg',
#  './dataset/Ugly Design 68.jpg',
#  './dataset/Ugly Design 146.jpg',
#  './dataset/Ugly Design 155.jpg',
#  './dataset/Ugly Design 254.jpg',
#  './dataset/Ugly Design 41.jpg',
#  './dataset/Ugly Design 20.jpg',
#  './dataset/Ugly Design 66.jpg',
#  './dataset/Ugly Design 141.jpg',
#  './dataset/Ugly Design 239.jpg',
#  './dataset/Ugly Design 284.jpg',
#  './dataset/Ugly Design 56.jpg',
#  './dataset/Ugly Design 276.jpg',
#  './dataset/Ugly Design 184.jpg',
#  './dataset/Ugly Design 127.jpg',
#  './dataset/Ugly Design 278.jpg',
#  './dataset/Ugly Design 90.jpg',
#  './dataset/Ugly Design 197.jpg',
#  './dataset/Ugly Design 23.jpg',
#  './dataset/Ugly Design 245.jpg',
#  './dataset/Ugly Design 16.jpg',
#  './dataset/Ugly Design 1.jpg',
#  './dataset/Ugly Design 102.jpg',
#  './dataset/Ugly Design 207.jpg',
#  './dataset/Ugly Design 37.jpg',
#  './dataset/Ugly Design 11.jpg',
#  './dataset/Ugly Design 134.jpg',
#  './dataset/Ugly Design 57.jpg',
#  './dataset/Ugly Design 63.jpg',
#  './dataset/Ugly Design 60.jpg',
#  './dataset/Ugly Design 167.jpg',
#  './dataset/Ugly Design 89.jpg',
#  './dataset/Ugly Design 32.jpg',
#  './dataset/Ugly Design 165.jpg',
#  './dataset/Ugly Design 280.jpg',
#  './dataset/Ugly Design 46.jpg',
#  './dataset/Ugly Design 224.jpg',
#  './dataset/Ugly Design 285.jpg',
#  './dataset/Ugly Design 189.jpg',
#  './dataset/Ugly Design 85.jpg',
#  './dataset/Ugly Design 265.jpg',
#  './dataset/Ugly Design 5.jpg',
#  './dataset/Ugly Design 69.jpg',
#  './dataset/Ugly Design 135.jpg',
#  './dataset/Ugly Design 72.jpg',
#  './dataset/Ugly Design 83.jpg',
#  './dataset/Ugly Design 256.jpg',
#  './dataset/Ugly Design 252.jpg',
#  './dataset/Ugly Design 100.jpg',
#  './dataset/Ugly Design 255.jpg',
#  './dataset/Ugly Design 233.jpg',
#  './dataset/Ugly Design 107.jpg',
#  './dataset/Ugly Design 158.jpg',
#  './dataset/Ugly Design 88.jpg',
#  './dataset/Ugly Design 117.jpg',
#  './dataset/Ugly Design 258.jpg',
#  './dataset/Ugly Design 115.jpg',
#  './dataset/Ugly Design 51.jpg',
#  './dataset/Ugly Design 131.jpg',
#  './dataset/Ugly Design 40.jpg',
#  './dataset/Ugly Design 260.jpg',
#  './dataset/Ugly Design 201.jpg',
#  './dataset/Ugly Design 266.jpg',
#  './dataset/Ugly Design 108.jpg',
#  './dataset/Ugly Design 94.jpg',
#  './dataset/Ugly Design 49.jpg',
#  './dataset/Ugly Design 249.jpg',
#  './dataset/Ugly Design 17.jpg',
#  './dataset/Ugly Design 93.jpg',
#  './dataset/Ugly Design 128.jpg',
#  './dataset/Ugly Design 6.jpg',
#  './dataset/Ugly Design 206.jpg',
#  './dataset/Ugly Design 222.jpg',
#  './dataset/Ugly Design 109.jpg',
#  './dataset/Ugly Design 187.jpg',
#  './dataset/Ugly Design 35.jpg',
#  './dataset/Ugly Design 55.jpg',
#  './dataset/Ugly Design 14.jpg']

# %%
import numpy as np

features = []

for i, image_path in enumerate(images):
#     print(image_path)
    if i % 10 == 0:
        print('we just analyzed' + str(i) + ' out of ' + str(len(images)))
    # here is where you would extract the dominant color and then
    # save to the feature list
    img = image.load_img(image_path, target_size=model.input_shape[1:3])
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    feat = feat_extractor.predict(x)[0]
    features.append(feat)
# Out:
# we just analyzed0 out of 300
# we just analyzed10 out of 300
# we just analyzed20 out of 300
# we just analyzed30 out of 300
# we just analyzed40 out of 300
# we just analyzed50 out of 300
# we just analyzed60 out of 300
# we just analyzed70 out of 300
# we just analyzed80 out of 300
# we just analyzed90 out of 300
# we just analyzed100 out of 300
# we just analyzed110 out of 300
# we just analyzed120 out of 300
# we just analyzed130 out of 300
# we just analyzed140 out of 300
# we just analyzed150 out of 300
# we just analyzed160 out of 300
# we just analyzed170 out of 300
# we just analyzed180 out of 300
# we just analyzed190 out of 300
# we just analyzed200 out of 300
# we just analyzed210 out of 300
# we just analyzed220 out of 300
# we just analyzed230 out of 300
# we just analyzed240 out of 300
# we just analyzed250 out of 300
# we just analyzed260 out of 300
# we just analyzed270 out of 300
# we just analyzed280 out of 300
# we just analyzed290 out of 300

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
scaled = ss.fit_transform(features)

# %%
from sklearn.cluster import MiniBatchKMeans

sum_squared = []

K = range(1, 20)

for i in K:
    print('Calculating ' + str(i))
    kmeans = MiniBatchKMeans(n_clusters=i)
    kmeans.fit(scaled)
    sum_squared.append(kmeans.inertia_)
# Out:
# Calculating 1
# Calculating 2
# Calculating 3
# Calculating 4
# Calculating 5
# Calculating 6
# Calculating 7
# Calculating 8
# Calculating 9
# Calculating 10
# Calculating 11
# Calculating 12
# Calculating 13
# Calculating 14
# Calculating 15
# Calculating 16
# Calculating 17
# Calculating 18
# Calculating 19

# %%
import matplotlib.pyplot as plt

plt.plot(K, sum_squared, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=12)
clusters = kmeans.fit_predict(scaled)

# %%
from sklearn.neighbors import NearestNeighbors

neighbors = NearestNeighbors(n_neighbors=5, metric='cosine').fit(scaled)
_, closest = neighbors.kneighbors(kmeans.cluster_centers_)

# %%
from PIL import Image

img_width = 200

grid_image = Image.new('RGB', (5 * img_width, len(closest) * 240), (0, 0, 0, 255))

max_height = 0
for cluster_row in closest:
    max_height_temp = 0
    xpos = 0
    for col_num in cluster_row:
        img = Image.open(images[col_num])
        img_ar = img.width / img.height
        img = img.resize((img_width, int(img_width / img_ar)), Image.ANTIALIAS)
        max_height_temp = max(max_height_temp, img.height)
        grid_image.paste(img, (xpos, max_height))
        xpos = xpos + img.width
    max_height = max_height + max_height_temp + 20 # adding 20 pixel margin

plt.figure(figsize = (32,24))
plt.imshow(grid_image)

# %%
import umap

embedding = umap.UMAP().fit_transform(scaled)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(embedding)
embedding_scaled = scaler.transform(embedding)

# %%
width = 4000
height = 2000
max_dim = 100

full_image = Image.new('RGBA', (width, height), (0, 0, 0, 0))
for img, pos in zip(images, embedding_scaled):
    x = pos[0]
    y = pos[1]
    tile = Image.open(img)
    rs = max(1, tile.width/max_dim, tile.height/max_dim)
    tile = tile.resize((int(tile.width/rs), int(tile.height/rs)), Image.ANTIALIAS)
    full_image.paste(tile, (int((width-max_dim)*x), int((height-max_dim)*y)), mask=tile.convert('RGBA'))

plt.figure(figsize = (32,24))
plt.imshow(full_image)

# %%
import rasterfairy

nx = 20
ny = 15

grid_assignment = rasterfairy.transformPointCloud2D(embedding, target=(nx, ny))

# %%
grid_assignment[1]
# Out:
# (20, 15)

# %%
tile_width = 100
tile_height = 100

full_width = tile_width * nx
full_height = tile_height * ny
aspect_ratio = tile_width / tile_height

grid_image = Image.new('RGB', (full_width, full_height), (0, 0, 0, 0))

print(grid_image)

for img, grid_pos in zip(images, grid_assignment[0]):
    idx_x, idx_y = grid_pos
    x, y = tile_width * idx_x, tile_height * idx_y
    tile = Image.open(img)
    tile_ar = tile.width / tile.height
    tile = tile.resize((int(0.8 * tile_width), int(0.8 * tile_height / tile_ar)), Image.ANTIALIAS)
    grid_image.paste(tile, (int(x), int(y)))

plt.figure(figsize = (16,12))
plt.imshow(grid_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x1500 at 0x7FFA6EFDAC10>

# %%
lookup = []

for image, grid_pos, cluster_pos in zip(images, grid_assignment[0], embedding_scaled):
    lookup.append({
#         "filename": image.replace('./dataset/', '').replace(' ', '_').replace(':', '_'),
        "filename": image.replace('./', ''),
        "grid_pos": grid_pos.tolist(),
        "cluster_pos": cluster_pos.tolist()
    })

# %%
lookup[100]
# Out:
# {'filename': 'dataset/Ugly Design 92.jpg',
#  'grid_pos': [13.0, 11.0],
#  'cluster_pos': [0.7492176294326782, 0.8359928131103516]}

# %%
import json

with open('image_umap_position.json', 'w') as outfile:
    json.dump(lookup, outfile)
